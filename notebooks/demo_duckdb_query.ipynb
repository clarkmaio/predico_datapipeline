# %% [markdown]
# # Load data
# You can query data using SQL syntax using `duckdb` package.
#
# `.parquet` files on Huggingface will work as a database.

# %%
import duckdb
QUERY = f"SELECT * FROM 'hf://datasets/clarkmaio/elia_predico/target.parquet'"
conn = duckdb.connect()
result = conn.execute(QUERY).fetchdf()
result.head()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                    datetime resolutioncode offshoreonshore   region  \
# 0 2017-01-01 01:00:00+01:00          PT15M        Offshore  Federal
# 1 2017-01-01 01:15:00+01:00          PT15M        Offshore  Federal
# 2 2017-01-01 01:30:00+01:00          PT15M        Offshore  Federal
# 3 2017-01-01 01:45:00+01:00          PT15M        Offshore  Federal
# 4 2017-01-01 02:00:00+01:00          PT15M        Offshore  Federal
#
#   gridconnectiontype  realtime  mostrecentforecast  mostrecentconfidence10  \
# 0               Elia       NaN              399.71                  227.98
# 1               Elia       NaN              401.23                  231.16
# 2               Elia       NaN              402.75                  234.34
# 3               Elia       NaN              404.27                  237.51
# 4               Elia       NaN              405.81                  239.17
#
# ...

# %%
import duckdb
QUERY = f"SELECT * FROM 'hf://datasets/clarkmaio/elia_predico/gfs_lastrun.parquet'"
conn = duckdb.connect()
result_weather = conn.execute(QUERY).fetchdf()
result_weather.head()
# Out:
#    latitude  longitude                time  step          valid_time   u10  \
# 0      51.5       2.50 2024-12-11 06:00:00     0 2024-12-11 06:00:00 -7.21
# 1      51.5       2.75 2024-12-11 06:00:00     0 2024-12-11 06:00:00 -6.97
# 2      51.5       3.00 2024-12-11 06:00:00     0 2024-12-11 06:00:00 -6.65
# 3      51.5       3.25 2024-12-11 06:00:00     0 2024-12-11 06:00:00 -5.95
# 4      51.5       3.50 2024-12-11 06:00:00     0 2024-12-11 06:00:00 -5.12
#
#     v10  gust  cape  __index_level_0__
# 0 -3.79   8.4   5.0                  0
# 1 -3.60   8.2   4.0                  1
# 2 -3.37   7.9   4.0                  2
# 3 -3.17   7.5   2.0                  3
# 4 -3.04   7.3   2.0                  4
